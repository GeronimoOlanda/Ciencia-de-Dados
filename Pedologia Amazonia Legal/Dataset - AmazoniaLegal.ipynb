# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pa= pd.read_csv('PedologiaAmazoniaLegal_250.csv')

# %%
pa.describe()
# Out:
#        Quantidade_Componentes  Area_Poligono_Km2
# count            62495.000000       62495.000000
# mean                 1.661381          80.135319
# std                  1.374426         516.927624
# min                  0.000000           0.004000
# 25%                  0.000000           0.144000
# 50%                  2.000000           1.498000
# 75%                  3.000000          19.411500
# max                  7.000000       59714.359000

# %%
pa.info() ## exibe a quantidade de informações
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62495 entries, 0 to 62494
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   FID                                 62495 non-null  object
#  1   Folha                               62495 non-null  object
#  2   Unidade_Mapeamento                  62495 non-null  object
#  3   Quantidade_Componentes              62495 non-null  int64
#  4   Solo_ou_Terreno                     62495 non-null  object
#  5   Simbolo_Unidade                     62495 non-null  object
#  6   Ordem                               40691 non-null  object
#  7   Subordem                            40323 non-null  object
#  8   Grande_Grupo                        40323 non-null  object
#  9   Subgrupo                            40323 non-null  object
#  10  Descricao                           40691 non-null  object
# ...

# %%
pa.shape ## mostra quantidade de linhas e colunas
# Out:
# (62495, 20)

# %%
pa.columns
# Out:
# Index(['FID', 'Folha', 'Unidade_Mapeamento', 'Quantidade_Componentes',
#        'Solo_ou_Terreno', 'Simbolo_Unidade', 'Ordem', 'Subordem',
#        'Grande_Grupo', 'Subgrupo', 'Descricao', 'Inclusoes',
#        'Textura_Principal_Componente', 'Horizonte_Principal_Componente',
#        'Erosao_Principal_Componente', 'Pedregosidade_Principal_Componente',
#        'Rochosidade_Principal_Componente', 'Relevo_Principal_Componente',
#        'Area_Poligono_Km2', 'the_geom'],
#       dtype='object')

# %%
pa.head()
# Out:
#                                                  FID Folha Unidade_Mapeamento  \
# 0  PedologiaAmazoniaLegal_250.fid--879d9bb_17233b...  NA19                AR6
# 1  PedologiaAmazoniaLegal_250.fid--879d9bb_17233b...  NA19               AR14
# 2  PedologiaAmazoniaLegal_250.fid--879d9bb_17233b...  NA19               AR14
# 3  PedologiaAmazoniaLegal_250.fid--879d9bb_17233b...  NA19               AR14
# 4  PedologiaAmazoniaLegal_250.fid--879d9bb_17233b...  NA19               PAa1
#
#    Quantidade_Componentes                    Solo_ou_Terreno Simbolo_Unidade  \
# 0                       2        AR - Afloramentos De Rochas              AR
# 1                       3        AR - Afloramentos De Rochas              AR
# 2                       3        AR - Afloramentos De Rochas              AR
# 3                       3        AR - Afloramentos De Rochas              AR
# 4                       2  PAa - Argissolo Amarelo Alumínico             PAa
#
# ...

# %%
pa.drop(['FID'],axis=1,inplace=True) ##Eliminando a coluna FIZ para uma analise mais precisa

# %%
pa.head()
# Out:
#   Folha Unidade_Mapeamento  Quantidade_Componentes  \
# 0  NA19                AR6                       2
# 1  NA19               AR14                       3
# 2  NA19               AR14                       3
# 3  NA19               AR14                       3
# 4  NA19               PAa1                       2
#
#                      Solo_ou_Terreno Simbolo_Unidade                   Ordem  \
# 0        AR - Afloramentos De Rochas              AR  AFLORAMENTOS DE ROCHAS
# 1        AR - Afloramentos De Rochas              AR  AFLORAMENTOS DE ROCHAS
# 2        AR - Afloramentos De Rochas              AR  AFLORAMENTOS DE ROCHAS
# 3        AR - Afloramentos De Rochas              AR  AFLORAMENTOS DE ROCHAS
# 4  PAa - Argissolo Amarelo Alumínico             PAa               ARGISSOLO
#
#   Subordem Grande_Grupo   Subgrupo  \
# 0      NaN          NaN        NaN
# 1      NaN          NaN        NaN
# 2      NaN          NaN        NaN
# 3      NaN          NaN        NaN
# ...

# %%
pa.drop(['Solo_ou_Terreno'],axis=1,inplace=True) ##Eliminando a coluna Solo_ou_Terreno para uma analise mais precisa

# %%
pa.head() ##cabeçario
# Out:
#   Folha Unidade_Mapeamento  Quantidade_Componentes Simbolo_Unidade  \
# 0  NA19                AR6                       2              AR
# 1  NA19               AR14                       3              AR
# 2  NA19               AR14                       3              AR
# 3  NA19               AR14                       3              AR
# 4  NA19               PAa1                       2             PAa
#
#                     Ordem Subordem Grande_Grupo   Subgrupo  \
# 0  AFLORAMENTOS DE ROCHAS      NaN          NaN        NaN
# 1  AFLORAMENTOS DE ROCHAS      NaN          NaN        NaN
# 2  AFLORAMENTOS DE ROCHAS      NaN          NaN        NaN
# 3  AFLORAMENTOS DE ROCHAS      NaN          NaN        NaN
# 4               ARGISSOLO  AMARELO    Alumínico  abrúptico
#
#                                            Descricao  \
# 0  AFLORAMENTOS DE ROCHAS ondulado, forte ondulad...
# 1  AFLORAMENTOS DE ROCHAS forte ondulado\r\n NEOS...
# ...

# %%
pa.tail() ##ultimos do dataframe
# Out:
#       Folha Unidade_Mapeamento  Quantidade_Componentes Simbolo_Unidade  \
# 62490  SE22             FFc153                       3             FFc
# 62491  SE22             FFc153                       3             FFc
# 62492  SE22           000Magua                       0        000Magua
# 62493  SE22           000Magua                       0        000Magua
# 62494  SE22           000Magua                       0        000Magua
#
#              Ordem Subordem    Grande_Grupo          Subgrupo  \
# 62490  PLINTOSSOLO  PÉTRICO  Concrecionário  típico e léptico
# 62491  PLINTOSSOLO  PÉTRICO  Concrecionário  típico e léptico
# 62492          NaN      NaN             NaN               NaN
# 62493          NaN      NaN             NaN               NaN
# 62494          NaN      NaN             NaN               NaN
#
#                                                Descricao Inclusoes  \
# 62490  PLINTOSSOLO PÉTRICO Concrecionário típico e lé...       NaN
# ...

# %%
pa.dropna(axis=0)
# Out:
# Empty DataFrame
# Columns: [Folha, Unidade_Mapeamento, Quantidade_Componentes, Simbolo_Unidade, Ordem, Subordem, Grande_Grupo, Subgrupo, Descricao, Inclusoes, Textura_Principal_Componente, Horizonte_Principal_Componente, Erosao_Principal_Componente, Pedregosidade_Principal_Componente, Rochosidade_Principal_Componente, Relevo_Principal_Componente, Area_Poligono_Km2, the_geom]
# Index: []

# %%
pa.isnull() ##returna se alguma variavel essta vazia
# Out:
#        Folha  Unidade_Mapeamento  Quantidade_Componentes  Simbolo_Unidade  \
# 0      False               False                   False            False
# 1      False               False                   False            False
# 2      False               False                   False            False
# 3      False               False                   False            False
# 4      False               False                   False            False
# ...      ...                 ...                     ...              ...
# 62490  False               False                   False            False
# 62491  False               False                   False            False
# 62492  False               False                   False            False
# 62493  False               False                   False            False
# 62494  False               False                   False            False
#
#        Ordem  Subordem  Grande_Grupo  Subgrupo  Descricao  Inclusoes  \
# ...

# %%
pa.fillna(0, inplace=True) ##preenche as variaveis vazias

# %%
pa.isnull() ## verificando se as variaveis estao vazias,da para usar um if
# Out:
#        Folha  Unidade_Mapeamento  Quantidade_Componentes  Simbolo_Unidade  \
# 0      False               False                   False            False
# 1      False               False                   False            False
# 2      False               False                   False            False
# 3      False               False                   False            False
# 4      False               False                   False            False
# ...      ...                 ...                     ...              ...
# 62490  False               False                   False            False
# 62491  False               False                   False            False
# 62492  False               False                   False            False
# 62493  False               False                   False            False
# 62494  False               False                   False            False
#
#        Ordem  Subordem  Grande_Grupo  Subgrupo  Descricao  Inclusoes  \
# ...

# %%
pa.head()
# Out:
#   Folha Unidade_Mapeamento  Quantidade_Componentes Simbolo_Unidade  \
# 0  NA19                AR6                       2              AR
# 1  NA19               AR14                       3              AR
# 2  NA19               AR14                       3              AR
# 3  NA19               AR14                       3              AR
# 4  NA19               PAa1                       2             PAa
#
#                     Ordem Subordem Grande_Grupo   Subgrupo  \
# 0  AFLORAMENTOS DE ROCHAS        0            0          0
# 1  AFLORAMENTOS DE ROCHAS        0            0          0
# 2  AFLORAMENTOS DE ROCHAS        0            0          0
# 3  AFLORAMENTOS DE ROCHAS        0            0          0
# 4               ARGISSOLO  AMARELO    Alumínico  abrúptico
#
#                                            Descricao  \
# 0  AFLORAMENTOS DE ROCHAS ondulado, forte ondulad...
# 1  AFLORAMENTOS DE ROCHAS forte ondulado\r\n NEOS...
# ...

# %%
pa.query('Quantidade_Componentes > 8e4')
# Out:
# Empty DataFrame
# Columns: [Folha, Unidade_Mapeamento, Quantidade_Componentes, Simbolo_Unidade, Ordem, Subordem, Grande_Grupo, Subgrupo, Descricao, Inclusoes, Textura_Principal_Componente, Horizonte_Principal_Componente, Erosao_Principal_Componente, Pedregosidade_Principal_Componente, Rochosidade_Principal_Componente, Relevo_Principal_Componente, Area_Poligono_Km2, the_geom]
# Index: []

# %%
pa.rank() ## rankeando de 0 a n quantidades
# Out:
#        Quantidade_Componentes  Area_Poligono_Km2
# 0                     32842.5            43477.0
# 1                     49814.5            51918.0
# 2                     49814.5            52848.5
# 3                     49814.5            38598.5
# 4                     32842.5            51368.0
# ...                       ...                ...
# 62490                 49814.5            49491.5
# 62491                 49814.5            44950.5
# 62492                 10902.5             8754.5
# 62493                 10902.5             9340.0
# 62494                 10902.5            47441.0
#
# [62495 rows x 2 columns]

# %%
pa.skew() ## a assimetria
# Out:
# Quantidade_Componentes     0.005218
# Area_Poligono_Km2         39.028716
# dtype: float64

# %%
pa.kurt()
# Out:
# Quantidade_Componentes      -1.269694
# Area_Poligono_Km2         3312.519861
# dtype: float64

# %%
pa.std() ## desvio padrao
# Out:
# Quantidade_Componentes      1.374426
# Area_Poligono_Km2         516.927624
# dtype: float64

# %%
pa.median() #mediana total
# Out:
# Quantidade_Componentes    2.000
# Area_Poligono_Km2         1.498
# dtype: float64

# %%
pa['Quantidade_Componentes'].mean() #media da quantidade de componentes
# Out:
# 1.6613809104728379
